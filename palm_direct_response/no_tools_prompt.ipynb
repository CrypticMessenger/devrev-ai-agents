# %% [markdown]
# ##### Copyright 2023 Google LLC

# %%
# Install the client library and import necessary modules.
# !pip install google-generativeai
import google.generativeai as palm
import base64
import json
import pprint

# %%
# !pip install --upgrade -q google-api-python-client google-auth-httplib2 google-auth-oauthlib
# !pip install google-generativeai
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow

SCOPES = ['https://www.googleapis.com/auth/generative-language.tuning']

def load_creds():
    """Converts `oauth-client-id.json` to a credential object.

    This function caches the generated tokens to minimize the use of the
    consent screen.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'oauth-client-id.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
    return creds

# %%
import pprint
import google.generativeai as palm


creds = load_creds()

palm.configure(credentials=creds)

print()
print('Available base models:', [m.name for m in palm.list_tuned_models()])
print('My tuned models:', [m.name for m in palm.list_tuned_models()])
# Out:
# Available base models: ['tunedModels/trainv1-ck70je33ngb4']
# My tuned models: ['tunedModels/trainv1-ck70je33ngb4']

# %%
model = palm.get_tuned_model(f'tunedModels/trainv1-ck70je33ngb4')
model
# Out:
# TunedModel(name='tunedModels/trainv1-ck70je33ngb4',
#            source_model='models/text-bison-001',
#            base_model='models/text-bison-001',
#            display_name='train_v1',
#            description=...,
#            temperature=0.7,
#            top_p=0.95,
#            top_k=40,
#            state=<State.ACTIVE: 2>,
#            create_time=datetime.datetime(2023, 12, 3, 12, 26, 48, 791649, tzinfo=datetime.timezone.utc),
#            update_time=datetime.datetime(2023, 12, 3, 12, 28, 7, 512040, tzinfo=datetime.timezone.utc),
#            tuning_task=TuningTask(start_time=datetime.datetime(2023, 12, 3, 12, 26, 49, 625264, tzinfo=datetime.timezone.utc),
#                                   complete_time=datetime.datetime(2023, 12, 3, 12, 28, 7, 512040, tzinfo=datetime.timezone.utc),
#                                   snapshots=[...],
#                                   hyperparameters=Hyperparameters(epoch_count=5,
# ...

# %%
# # Configure the client library by providing your API key.
# palm.configure(api_key="AIzaSyAq9RCFh9Jx5t9oR20xWRAZdXsn-b01pT8")

# %%
# These parameters for the model call can be set by URL parameters.
model = 'tunedModels/trainv1-ck70je33ngb4' # @param {isTemplate: true}
temperature = 0 # @param {isTemplate: true}
candidate_count = 1 # @param {isTemplate: true}
top_k = 40 # @param {isTemplate: true}
top_p = 0.95 # @param {isTemplate: true}
max_output_tokens = 1024 # @param {isTemplate: true}
text_b64 = '...' # @param {isTemplate: true}
stop_sequences_b64 = 'W10=' # @param {isTemplate: true}
safety_settings_b64 = '...' # @param {isTemplate: true}

# Convert the prompt text param from a bae64 string to a string.
# text = base64.b64decode(text_b64).decode("utf-8")
# load json file and get the text corresponding to the key "prompt"
import json
with open('prompt_model.json') as f:
  data = json.load(f)
text = data["prompt"] + "Create actionable tasks from the text \"Review user feedback on the new feature\" and summarize the created tasks"
# Convert the stop_sequences and safety_settings params from base64 strings to lists.
stop_sequences = json.loads(base64.b64decode(stop_sequences_b64).decode("utf-8"))
safety_settings = json.loads(base64.b64decode(safety_settings_b64).decode("utf-8"))

defaults = {
  'model': model,
  'temperature': temperature,
  'candidate_count': candidate_count,
  'top_k': top_k,
  'top_p': top_p,
  'max_output_tokens': max_output_tokens,
  'stop_sequences': stop_sequences,
  'safety_settings': safety_settings,
}

# Show what will be sent with the API call.
pprint.pprint(defaults | {'prompt': text})
# Out:
# {'candidate_count': 1,
#  'max_output_tokens': 1024,
#  'model': 'tunedModels/trainv1-ck70je33ngb4',
#  'prompt': ' input:Prioritize my P0 issues and add them to the current sprint\n'
#            ' [\n'
#            '{\n'
#            '"tool_name": "whoami",\n'
#            '"arguments": []\n'
#            '},\n'
#            '{\n'
#            '"tool_name": "works_list",\n'
#            '"arguments": [\n'
#            '{\n'
#            '"argument_name": "issue.priority",\n'
#            '\n'
#            'Unset\n'
#            '"argument_value": ["p0"]\n'
#            '},\n'
#            '{\n'
#            '"argument_name": "owned_by",\n'
#            '"argument_value": ["$$PREV[0]"]\n'
#            '},\n'
#            '{\n'
#            '"argument_name": "type",\n'
#            '"argument_value": ["issue"]\n'
#            '}\n'
#            ']\n'
#            '},\n'
#            '{\n'
#            '"tool_name": "prioritize_objects",\n'
#            '"arguments": [\n'
# ...

# %%
# Call the model and print the response.
response = palm.generate_text(
  **defaults,
  prompt=text
)

# %%
print(response.candidates[0]['output'])
# Out:
#  [
#    {
#       "tool_name": "create_actionable_tasks_from_text",
#       "arguments": [
#          {
#             "argument_name": "text",
#             "argument_value": "Review user feedback on the new feature"
#          }
#       ]
#    },
#    {
#       "tool_name": "summarize_objects",
#       "arguments": [
#          {
#             "argument_name": "objects",
#             "argument_value": "$$PREV[0]"
#          }
#       ]
#    }
# ]
